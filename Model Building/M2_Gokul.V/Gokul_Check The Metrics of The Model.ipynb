# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error , r2_score
import joblib
# %matplotlib inline

# %%
data = pd.read_csv('./dataset.csv')
data.head()
# Out:
#           Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0  01 01 2018 00:00           380.047791          5.311336
# 1  01 01 2018 00:10           453.769196          5.672167
# 2  01 01 2018 00:20           306.376587          5.216037
# 3  01 01 2018 00:30           419.645905          5.659674
# 4  01 01 2018 00:40           380.650696          5.577941
#
#    Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                     416.328908          259.994904
# 1                     519.917511          268.641113
# 2                     390.900016          272.564789
# 3                     516.127569          271.258087
# 4                     491.702972          265.674286

# %%
data.shape
# Out:
# (50530, 5)

# %%
data.describe()
# Out:
#        LV ActivePower (kW)  Wind Speed (m/s)  Theoretical_Power_Curve (KWh)  \
# count         50530.000000      50530.000000                   50530.000000
# mean           1307.684332          7.557952                    1492.175463
# std            1312.459242          4.227166                    1368.018238
# min              -2.471405          0.000000                       0.000000
# 25%              50.677890          4.201395                     161.328167
# 50%             825.838074          7.104594                    1063.776283
# 75%            2482.507568         10.300020                    2964.972462
# max            3618.732910         25.206011                    3600.000000
#
#        Wind Direction (°)
# count        50530.000000
# mean           123.687559
# std             93.443736
# min              0.000000
# 25%             49.315437
# 50%             73.712978
# 75%            201.696720
# max            359.997589

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50530 entries, 0 to 50529
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date/Time                      50530 non-null  object
#  1   LV ActivePower (kW)            50530 non-null  float64
#  2   Wind Speed (m/s)               50530 non-null  float64
#  3   Theoretical_Power_Curve (KWh)  50530 non-null  float64
#  4   Wind Direction (°)             50530 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 1.9+ MB

# %%
data.isnull().any()
# Out:
# Date/Time                        False
# LV ActivePower (kW)              False
# Wind Speed (m/s)                 False
# Theoretical_Power_Curve (KWh)    False
# Wind Direction (°)               False
# dtype: bool

# %% [markdown]
# DATA PREPROCESSING

# %%
data['Date/Time'] = pd.to_datetime(data['Date/Time'],format='%d %m %Y %H:%M')
data['year'] = data['Date/Time'].dt.year 
data['month'] = data['Date/Time'].dt.month 
data['day'] = data['Date/Time'].dt.day
data['Hour'] = data['Date/Time'].dt.hour 
data['minute'] = data['Date/Time'].dt.minute 
data.head()
# Out:
#             Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0 2018-01-01 00:00:00           380.047791          5.311336
# 1 2018-01-01 00:10:00           453.769196          5.672167
# 2 2018-01-01 00:20:00           306.376587          5.216037
# 3 2018-01-01 00:30:00           419.645905          5.659674
# 4 2018-01-01 00:40:00           380.650696          5.577941
#
#    Theoretical_Power_Curve (KWh)  Wind Direction (°)  year  month  day  Hour  \
# 0                     416.328908          259.994904  2018      1    1     0
# 1                     519.917511          268.641113  2018      1    1     0
# 2                     390.900016          272.564789  2018      1    1     0
# 3                     516.127569          271.258087  2018      1    1     0
# 4                     491.702972          265.674286  2018      1    1     0
#
#    minute
# 0       0
# 1      10
# 2      20
# 3      30
# 4      40

# %%
data["Date/Time"] = pd.to_datetime(data["Date/Time"], format = "%d %m %Y %H:%M", errors = "coerce")
data
# Out:
#                 Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0     2018-01-01 00:00:00           380.047791          5.311336
# 1     2018-01-01 00:10:00           453.769196          5.672167
# 2     2018-01-01 00:20:00           306.376587          5.216037
# 3     2018-01-01 00:30:00           419.645905          5.659674
# 4     2018-01-01 00:40:00           380.650696          5.577941
# ...                   ...                  ...               ...
# 50525 2018-12-31 23:10:00          2963.980957         11.404030
# 50526 2018-12-31 23:20:00          1684.353027          7.332648
# 50527 2018-12-31 23:30:00          2201.106934          8.435358
# 50528 2018-12-31 23:40:00          2515.694092          9.421366
# 50529 2018-12-31 23:50:00          2820.466064          9.979332
#
#        Theoretical_Power_Curve (KWh)  Wind Direction (°)  year  month  day  \
# 0                         416.328908          259.994904  2018      1    1
# 1                         519.917511          268.641113  2018      1    1
# 2                         390.900016          272.564789  2018      1    1
# 3                         516.127569          271.258087  2018      1    1
# 4                         491.702972          265.674286  2018      1    1
# ...                              ...                 ...   ...    ...  ...
# 50525                    3397.190793           80.502724  2018     12   31
# 50526                    1173.055771           84.062599  2018     12   31
# 50527                    1788.284755           84.742500  2018     12   31
# 50528                    2418.382503           84.297913  2018     12   31
# 50529                    2779.184096           82.274620  2018     12   31
#
#        Hour  minute
# 0         0       0
# 1         0      10
# 2         0      20
# 3         0      30
# 4         0      40
# ...     ...     ...
# 50525    23      10
# 50526    23      20
# 50527    23      30
# 50528    23      40
# 50529    23      50
#
# [50530 rows x 10 columns]

# %% [markdown]
# DATASET SPLITTING

# %%
X=data[['Wind Speed (m/s)','Wind Direction (°)']]
X.head()
# Out:
#    Wind Speed (m/s)  Wind Direction (°)
# 0          5.311336          259.994904
# 1          5.672167          268.641113
# 2          5.216037          272.564789
# 3          5.659674          271.258087
# 4          5.577941          265.674286

# %%
X_train, X_test,y_train, y_test = train_test_split(X,y ,
                                   random_state=6, 
                                   test_size=0.25)

# %% [markdown]
# IMPORTING THE REGRESSION MODELS

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error
xgr=XGBRegressor()
rf=RandomForestRegressor()
lr=LinearRegression()
dt=DecisionTreeRegressor()
sm=SVR()

# %% [markdown]
# FILTERING THE MODELS WITH DATASET

# %%
model_xg=xgr.fit(X_train,y_train)
y_xg=model_xg.predict(X_test)
model_rf=rf.fit(X_train,y_train)
y_rf=model_rf.predict(X_test)
model_lr=lr.fit(X_train,y_train)
y_lr=model_lr.predict(X_test)
model_dt=dt.fit(X_train,y_train)
y_dt=model_dt.predict(X_test)
model_sm=sm.fit(X_train,y_train)
y_sm=model_sm.predict(X_test)

# %% [markdown]
# CHECKING THE METRICS

# %%
print('R2-xgb',r2_score(y_test,y_xg))
print('RMSE-xgb',np.sqrt(mean_squared_error(y_test,y_xg)))

print('R2-rf',r2_score(y_test,y_rf))
print('RMSE-rf',np.sqrt(mean_squared_error(y_test,y_rf)))

print('R2-lr',r2_score(y_test,y_lr))
print('RMSE-lr',np.sqrt(mean_squared_error(y_test,y_lr)))

print('R2-dt',r2_score(y_test,y_dt))
print('RMSE-dt',np.sqrt(mean_squared_error(y_test,y_dt)))

print('R2-svm',r2_score(y_test,y_sm))
print('RMSE-svm',np.sqrt(mean_squared_error(y_test,y_sm)))
# Out:
# R2-xgb 0.9197743106205652
# RMSE-xgb 370.6768884049128
# R2-rf 0.9091639024761513
# RMSE-rf 394.4282510406997
# R2-lr 0.8368251429450981
# RMSE-lr 528.646547634677
# R2-dt 0.8413476524047431
# RMSE-dt 521.269159878656
# R2-svm 0.005368134807760105
# RMSE-svm 1305.1786596858901

# %% [markdown]
# HYPERPARAMETER TURNING

# %%
params={
 "learning_rate"    : [0.05, 0.01,0.03,0.1, 0.15, 0.2] ,
 "n_estimators"     : [50, 100, 150, 200, 500, 800,1000,1500] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15,20,25],
 "min_child_weight" : [ 1, 3, 5, 7 ,10,15,20,25],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "subsample"        : [ 0.1, 0.2 , 0.3, 0.4,0.6,0.8,1 ],
 "reg_lambda"       : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ,0.6,0.8,1],
 "reg_alpha"        : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7,0.9 ],
 "colsample_bylevel" : [ 0.3, 0.4, 0.5 , 0.7,0.9 ]
    
}

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
random_search=RandomizedSearchCV(xgr,param_distributions=params,n_iter=10,n_jobs=-1,cv=5,verbose=3)
from datetime import datetime
start_time = timer(None)
random_search.fit(X_train,y_train)
timer(start_time)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 3/5] END colsample_bylevel=0.7, colsample_bytree=0.7, gamma=0.0, learning_rate=0.2, max_depth=3, min_child_weight=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.2, subsample=0.2;, score=0.906 total time=   1.8s
# [CV 1/5] END colsample_bylevel=0.7, colsample_bytree=0.7, gamma=0.0, learning_rate=0.2, max_depth=3, min_child_weight=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.2, subsample=0.2;, score=0.908 total time=   1.7s
# [CV 2/5] END colsample_bylevel=0.7, colsample_bytree=0.7, gamma=0.0, learning_rate=0.2, max_depth=3, min_child_weight=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.2, subsample=0.2;, score=0.904 total time=   1.8s
# [CV 4/5] END colsample_bylevel=0.7, colsample_bytree=0.7, gamma=0.0, learning_rate=0.2, max_depth=3, min_child_weight=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.2, subsample=0.2;, score=0.910 total time=   1.5s
# [CV 5/5] END colsample_bylevel=0.7, colsample_bytree=0.7, gamma=0.0, learning_rate=0.2, max_depth=3, min_child_weight=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.2, subsample=0.2;, score=0.904 total time=   1.5s
# [CV 1/5] END colsample_bylevel=0.7, colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.0, reg_lambda=0.8, subsample=0.6;, score=0.902 total time=   3.4s
# [CV 3/5] END colsample_bylevel=0.7, colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.0, reg_lambda=0.8, subsample=0.6;, score=0.896 total time=   3.8s
# [CV 2/5] END colsample_bylevel=0.7, colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.0, reg_lambda=0.8, subsample=0.6;, score=0.894 total time=   3.9s
# [CV 5/5] END colsample_bylevel=0.3, colsample_bytree=0.3, gamma=0.1, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=200, reg_alpha=0.2, reg_lambda=0.2, subsample=0.8;, score=0.750 total time=   7.4s
# [CV 4/5] END colsample_bylevel=0.3, colsample_bytree=0.3, gamma=0.1, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=200, reg_alpha=0.2, reg_lambda=0.2, subsample=0.8;, score=0.763 total time=   7.4s
# [CV 3/5] END colsample_bylevel=0.3, colsample_bytree=0.3, gamma=0.1, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=200, reg_alpha=0.2, reg_lambda=0.2, subsample=0.8;, score=0.766 total time=   7.4s
# [CV 2/5] END colsample_bylevel=0.3, colsample_bytree=0.3, gamma=0.1, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=200, reg_alpha=0.2, reg_lambda=0.2, subsample=0.8;, score=0.804 total time=   7.4s
# [CV 1/5] END colsample_bylevel=0.3, colsample_bytree=0.3, gamma=0.1, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=200, reg_alpha=0.2, reg_lambda=0.2, subsample=0.8;, score=0.804 total time=   7.6s
# [CV 4/5] END colsample_bylevel=0.7, colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.0, reg_lambda=0.8, subsample=0.6;, score=0.903 total time=   3.7s
# [CV 5/5] END colsample_bylevel=0.7, colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=500, reg_alpha=0.0, reg_lambda=0.8, subsample=0.6;, score=0.897 total time=   3.6s
# [CV 1/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=200, reg_alpha=0.3, reg_lambda=0.3, subsample=0.1;, score=0.901 total time=   3.9s
# [CV 2/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=200, reg_alpha=0.3, reg_lambda=0.3, subsample=0.1;, score=0.896 total time=   3.8s
# [CV 3/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=200, reg_alpha=0.3, reg_lambda=0.3, subsample=0.1;, score=0.898 total time=   3.7s
# [CV 1/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.2, learning_rate=0.05, max_depth=5, min_child_weight=20, n_estimators=100, reg_alpha=0.2, reg_lambda=1, subsample=0.3;, score=0.904 total time=   0.6s
# [CV 4/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=200, reg_alpha=0.3, reg_lambda=0.3, subsample=0.1;, score=0.902 total time=   3.9s
# [CV 2/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.2, learning_rate=0.05, max_depth=5, min_child_weight=20, n_estimators=100, reg_alpha=0.2, reg_lambda=1, subsample=0.3;, score=0.898 total time=   0.6s
# [CV 3/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.2, learning_rate=0.05, max_depth=5, min_child_weight=20, n_estimators=100, reg_alpha=0.2, reg_lambda=1, subsample=0.3;, score=0.898 total time=   0.6s
# [CV 4/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.2, learning_rate=0.05, max_depth=5, min_child_weight=20, n_estimators=100, reg_alpha=0.2, reg_lambda=1, subsample=0.3;, score=0.903 total time=   0.6s
# [CV 5/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=20, min_child_weight=3, n_estimators=200, reg_alpha=0.3, reg_lambda=0.3, subsample=0.1;, score=0.895 total time=   3.8s
# [CV 5/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.2, learning_rate=0.05, max_depth=5, min_child_weight=20, n_estimators=100, reg_alpha=0.2, reg_lambda=1, subsample=0.3;, score=0.897 total time=   0.6s
# [CV 3/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=8, min_child_weight=25, n_estimators=1500, reg_alpha=0.3, reg_lambda=0.1, subsample=0.6;, score=0.907 total time=  15.9s
# [CV 4/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=8, min_child_weight=25, n_estimators=1500, reg_alpha=0.3, reg_lambda=0.1, subsample=0.6;, score=0.913 total time=  16.1s
# [CV 2/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=8, min_child_weight=25, n_estimators=1500, reg_alpha=0.3, reg_lambda=0.1, subsample=0.6;, score=0.906 total time=  16.3s
# [CV 5/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=8, min_child_weight=25, n_estimators=1500, reg_alpha=0.3, reg_lambda=0.1, subsample=0.6;, score=0.906 total time=  16.2s
# [CV 1/5] END colsample_bylevel=0.5, colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=8, min_child_weight=25, n_estimators=1500, reg_alpha=0.3, reg_lambda=0.1, subsample=0.6;, score=0.910 total time=  16.5s
# [CV 1/5] END colsample_bylevel=0.4, colsample_bytree=0.9, gamma=0.4, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.4, subsample=0.8;, score=0.904 total time=   0.6s
# [CV 2/5] END colsample_bylevel=0.4, colsample_bytree=0.9, gamma=0.4, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.4, subsample=0.8;, score=0.898 total time=   0.6s
# [CV 3/5] END colsample_bylevel=0.4, colsample_bytree=0.9, gamma=0.4, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.4, subsample=0.8;, score=0.898 total time=   0.5s
# [CV 1/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=10, n_estimators=50, reg_alpha=0.4, reg_lambda=0.4, subsample=0.4;, score=0.912 total time=   0.3s
# [CV 4/5] END colsample_bylevel=0.4, colsample_bytree=0.9, gamma=0.4, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.4, subsample=0.8;, score=0.904 total time=   0.7s
# [CV 5/5] END colsample_bylevel=0.4, colsample_bytree=0.9, gamma=0.4, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.4, subsample=0.8;, score=0.897 total time=   0.7s
# [CV 2/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=10, n_estimators=50, reg_alpha=0.4, reg_lambda=0.4, subsample=0.4;, score=0.907 total time=   0.4s
# [CV 3/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=10, n_estimators=50, reg_alpha=0.4, reg_lambda=0.4, subsample=0.4;, score=0.908 total time=   0.4s
# [CV 4/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=10, n_estimators=50, reg_alpha=0.4, reg_lambda=0.4, subsample=0.4;, score=0.914 total time=   0.4s
# [CV 5/5] END colsample_bylevel=0.9, colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=10, n_estimators=50, reg_alpha=0.4, reg_lambda=0.4, subsample=0.4;, score=0.906 total time=   0.3s
# [CV 1/5] END colsample_bylevel=0.9, colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=200, reg_alpha=0.1, reg_lambda=0.2, subsample=0.8;, score=0.902 total time=   3.7s
# [CV 2/5] END colsample_bylevel=0.9, colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=200, reg_alpha=0.1, reg_lambda=0.2, subsample=0.8;, score=0.897 total time=   3.7s
# [CV 3/5] END colsample_bylevel=0.9, colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=200, reg_alpha=0.1, reg_lambda=0.2, subsample=0.8;, score=0.898 total time=   3.6s
# [CV 4/5] END colsample_bylevel=0.9, colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=200, reg_alpha=0.1, reg_lambda=0.2, subsample=0.8;, score=0.903 total time=   3.3s
# [CV 5/5] END colsample_bylevel=0.9, colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=15, min_child_weight=15, n_estimators=200, reg_alpha=0.1, reg_lambda=0.2, subsample=0.8;, score=0.896 total time=   3.4s
# [CV 1/5] END colsample_bylevel=0.4, colsample_bytree=0.4, gamma=0.0, learning_rate=0.05, max_depth=25, min_child_weight=10, n_estimators=1000, reg_alpha=0.3, reg_lambda=0.0, subsample=0.4;, score=0.890 total time=  27.3s
# [CV 2/5] END colsample_bylevel=0.4, colsample_bytree=0.4, gamma=0.0, learning_rate=0.05, max_depth=25, min_child_weight=10, n_estimators=1000, reg_alpha=0.3, reg_lambda=0.0, subsample=0.4;, score=0.882 total time=  27.4s
# [CV 3/5] END colsample_bylevel=0.4, colsample_bytree=0.4, gamma=0.0, learning_rate=0.05, max_depth=25, min_child_weight=10, n_estimators=1000, reg_alpha=0.3, reg_lambda=0.0, subsample=0.4;, score=0.886 total time=  27.4s
# [CV 4/5] END colsample_bylevel=0.4, colsample_bytree=0.4, gamma=0.0, learning_rate=0.05, max_depth=25, min_child_weight=10, n_estimators=1000, reg_alpha=0.3, reg_lambda=0.0, subsample=0.4;, score=0.892 total time=  25.6s
# [CV 5/5] END colsample_bylevel=0.4, colsample_bytree=0.4, gamma=0.0, learning_rate=0.05, max_depth=25, min_child_weight=10, n_estimators=1000, reg_alpha=0.3, reg_lambda=0.0, subsample=0.4;, score=0.884 total time=  25.4s
#
#  Time taken: 0 hours 0 minutes and 51.17 seconds.

# %%
random_search.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=0.9, colsample_bynode=1, colsample_bytree=0.7,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.1, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.2, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=4, max_leaves=0, min_child_weight=10, missing=nan,
#              monotone_constraints='()', n_estimators=50, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
xg=XGBRegressor(colsample_bylevel=0.4, colsample_bytree=0.3, gamma=0.1,
             learning_rate=0.01, max_depth=6, min_child_weight=25,
             n_estimators=1500, reg_alpha=0.1, reg_lambda=0.8, subsample=0.6)
x=xgr.fit(X_train,y_train)
y1=x.predict(X_test)
r2_score(y_test,y1)
# Out:
# 0.9197743106205652
